# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("titanic_train.csv")

# %%
df.head
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Data to do :
# 1. Extract the Mr/Mrs/Miss/Master
# 2. fill in age
# 3. Extract family name
# 4. Extract Ticket Prefix

# %%
df['Name'].str.split(",")[0][0]
# Out:
# 'Braund'

# %%
family_name = []
for i in range(0,891):
    family_name.append(df['Name'].str.split(",")[i][0])

# %%
df['family name']=family_name

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Cabin          687
# Age            177
# Embarked         2
# family name      0
# Fare             0
# Ticket           0
# Parch            0
# SibSp            0
# Sex              0
# Name             0
# Pclass           0
# Survived         0
# PassengerId      0
# dtype: int64

# %%
import re
re.findall('([A-Z]+[\/\.]?[\/|\.]?\S+)')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-2f2a00d0e13c> in <module>
# ----> 1 re.findall('([A-Z]+[\/\.]?[\/|\.]?\S+)',df['Ticket'])
#
# ~/anaconda3/envs/algoritma/lib/python3.8/re.py in findall(pattern, string, flags)
#     237
#     238     Empty matches are included in the result."""
# --> 239     return _compile(pattern, flags).findall(string)
#     240
#     241 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
ticket_prefix=[]
for ticket in df['Ticket']:
    ticket_prefix.append(re.findall('([A-Z]+[\/\.]?[\/|\.]?\S+)',ticket))

# %%
ticket_prefix
# Out:
# [['A/5'],
#  ['PC'],
#  ['STON/O2.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PP'],
#  [],
#  ['A/5.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['PC'],
#  ['PC'],
#  [],
#  ['C.A.'],
#  ['PC'],
#  [],
#  [],
#  ['A./5.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['SC/Paris'],
#  [],
#  ['S.C./A.4.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['A/4.'],
#  ['PC'],
#  [],
#  [],
#  [],
#  ['C.A.'],
#  [],
#  ['C.A.'],
#  ['CA'],
#  [],
#  [],
#  [],
#  [],
#  ['PC'],
#  [],
#  ['C.A.'],
#  ['S.P.'],
#  [],
#  [],
#  ['C.A.'],
#  ['CA'],
#  ['S.O.C.'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['SO/C'],
#  [],
#  ['W./C.'],
#  ['SOTON/OQ'],
#  [],
#  [],
#  [],
#  [],
#  ['W.E.P.'],
#  ['C.A.'],
#  [],
#  [],
#  ['PC'],
#  ['PC'],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  [],
#  ['STON/O'],
# ...

# %%
ticket_number=[]
for ticket in df['Ticket']:
    ticket_number.append(re.findall('\d+\s?$',ticket))

# %%
ticket_number
# Out:
# [['21171'],
#  ['17599'],
#  ['3101282'],
#  ['113803'],
#  ['373450'],
#  ['330877'],
#  ['17463'],
#  ['349909'],
#  ['347742'],
#  ['237736'],
#  ['9549'],
#  ['113783'],
#  ['2151'],
#  ['347082'],
#  ['350406'],
#  ['248706'],
#  ['382652'],
#  ['244373'],
#  ['345763'],
#  ['2649'],
#  ['239865'],
#  ['248698'],
#  ['330923'],
#  ['113788'],
#  ['349909'],
#  ['347077'],
#  ['2631'],
#  ['19950'],
#  ['330959'],
#  ['349216'],
#  ['17601'],
#  ['17569'],
#  ['335677'],
#  ['24579'],
#  ['17604'],
#  ['113789'],
#  ['2677'],
#  ['2152'],
#  ['345764'],
#  ['2651'],
#  ['7546'],
#  ['11668'],
#  ['349253'],
#  ['2123'],
#  ['330958'],
#  ['23567'],
#  ['370371'],
#  ['14311'],
#  ['2662'],
#  ['349237'],
#  ['3101295'],
#  ['39886'],
#  ['17572'],
#  ['2926'],
#  ['113509'],
#  ['19947'],
#  ['31026'],
#  ['2697'],
#  ['34651'],
#  ['2144'],
#  ['2669'],
#  ['113572'],
#  ['36973'],
#  ['347088'],
#  ['17605'],
#  ['2661'],
#  ['29395'],
#  ['3464'],
#  ['3101281'],
# ...

# %%
name_prefix=[]
for name in df['Name']:
    name_prefix.append(re.findall('(Mr|Mrs|Miss|Master)',name))

# %%
for name in name_prefix:
    print(name_prefix)[name][0]
# Out:
# [['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Master'], ['Mr'], ['Mr'], ['Miss'], ['Miss'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Master'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], [], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Miss'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Master'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Miss'], ['Master'], ['Mr'], ['Miss'], ['Mr'], ['Master'], ['Mr'], ['Master'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Master'], ['Miss'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Mr'], ['Miss'], ['Mr'], ['Miss'], ['Mr'], ['Miss'], ['Miss'
# ...
